# %%
# Importando os pacotes necessários

import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import prince
import plotly.io as pio
pio.renderers.default = 'browser'
import plotly.graph_objects as go
from itertools import combinations

# %% [markdown]
# ### Análise de Correspondência Simples (ANACOR)

# %%
# Importando o banco de dados
dados_mca = pd.read_excel("/Users/administrador/Documents/usp_ds_analytics/usp_ds_analytics/anacor_mca/data/dados_cor_acm.xlsx")

# %%
dados_mca.head()
# Out:
#    idade       sexo      dor.peito  ps.descanco  colesterol acucar.sangue  \
# 0     40  Masculino        Atipica          140         289        Normal
# 1     49   Feminino        Sem_Dor          160         180        Normal
# 2     37  Masculino        Atipica          130         283        Normal
# 3     48   Feminino  Assintomatico          138         214        Normal
# 4     54  Masculino        Sem_Dor          150         195        Normal
#
#   ecg.descanco  bc.max angina.exerc doenca.card
# 0       Normal     172          Nao         Nao
# 1       Normal     156          Nao         Sim
# 2   Anormal_ST      98          Nao         Nao
# 3       Normal     108          Sim         Sim
# 4       Normal     122          Nao         Nao

# %%
dados_mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   idade          918 non-null    int64
#  1   sexo           918 non-null    object
#  2   dor.peito      918 non-null    object
#  3   ps.descanco    918 non-null    int64
#  4   colesterol     918 non-null    int64
#  5   acucar.sangue  918 non-null    object
#  6   ecg.descanco   918 non-null    object
#  7   bc.max         918 non-null    int64
#  8   angina.exerc   918 non-null    object
#  9   doenca.card    918 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 71.8+ KB

# %%
dados_mca.describe(include='all').T
# Out:
#                count unique            top freq        mean         std   min  \
# idade          918.0    NaN            NaN  NaN   53.510893    9.432617  28.0
# sexo             918      2      Masculino  725         NaN         NaN   NaN
# dor.peito        918      4  Assintomatico  496         NaN         NaN   NaN
# ps.descanco    918.0    NaN            NaN  NaN  132.396514   18.514154   0.0
# colesterol     918.0    NaN            NaN  NaN  198.799564  109.384145   0.0
# acucar.sangue    918      2         Normal  704         NaN         NaN   NaN
# ecg.descanco     918      3         Normal  552         NaN         NaN   NaN
# bc.max         918.0    NaN            NaN  NaN  136.809368   25.460334  60.0
# angina.exerc     918      2            Nao  547         NaN         NaN   NaN
# doenca.card      918      2            Sim  508         NaN         NaN   NaN
#
#                   25%    50%    75%    max
# idade            47.0   54.0   60.0   77.0
# sexo              NaN    NaN    NaN    NaN
# dor.peito         NaN    NaN    NaN    NaN
# ps.descanco     120.0  130.0  140.0  200.0
# colesterol     173.25  223.0  267.0  603.0
# acucar.sangue     NaN    NaN    NaN    NaN
# ecg.descanco      NaN    NaN    NaN    NaN
# bc.max          120.0  138.0  156.0  202.0
# angina.exerc      NaN    NaN    NaN    NaN
# doenca.card       NaN    NaN    NaN    NaN

# %% [markdown]
# Temos variáveis métricas e categóricas.
# Vamos categorizar estas variáveis métricas?

# %%
# Vamos categorizar utilizando um critério quantitativo

dados_mca['idade'] = pd.qcut(dados_mca['idade'], 3, labels=list(['menores_idades', 'idades_medias', 'maiores_idades']))
dados_mca['ps.descanco'] = pd.qcut(dados_mca['ps.descanco'], 3, labels=list(['ps_baixa', 'ps_media', 'ps_alta']))
dados_mca['colesterol'] = pd.qcut(dados_mca['colesterol'], 3, labels=list(['col_baixo', 'col_medio', 'col_alto']))
dados_mca['bc.max'] = pd.qcut(dados_mca['bc.max'], 3, labels=list(['bc_baixo', 'bc_medio', 'bc_alto']))

# %%
# Informações descritivas sobre as variáveis

print(dados_mca['idade'].value_counts())
print("")
print(dados_mca['ps.descanco'].value_counts())
print("")
print(dados_mca['colesterol'].value_counts())
print("")
print(dados_mca['bc.max'].value_counts())
# Out:
# idade
# menores_idades    316
# idades_medias     314
# maiores_idades    288
# Name: count, dtype: int64
#
# ps.descanco
# ps_media    391
# ps_baixa    307
# ps_alta     220
# Name: count, dtype: int64
#
# colesterol
# col_baixo    309
# col_alto     305
# col_medio    304
# Name: count, dtype: int64
#
# bc.max
# bc_baixo    323
# bc_medio    317
# bc_alto     278
# Name: count, dtype: int64

# %% [markdown]
# ### Criando a tabela de contingência

# %%
# A seguir, a função extrai todas as tabelas de contingência possíveis

for item in list(combinations(dados_mca.columns, 2)):
    print(item, "\n")
    tabela = pd.crosstab(dados_mca[item[0]], dados_mca[item[1]])
    
    print(tabela)
    
    chi2, pvalor, gl, freq_esp = chi2_contingency(tabela)

    print(f"estatística qui²: {round(chi2, 2)}")
    print(f"p-valor da estatística: {round(pvalor, 4)}", "\n")
# Out:
# ('idade', 'sexo')
#
# sexo            Feminino  Masculino
# idade
# menores_idades        78        238
# idades_medias         62        252
# maiores_idades        53        235
# estatística qui²: 4.05
# p-valor da estatística: 0.132
#
# ('idade', 'dor.peito')
#
# dor.peito       Assintomatico  Atipica  Sem_Dor  Tipica
# idade
# menores_idades            142       86       74      14
# idades_medias             169       67       70       8
# maiores_idades            185       20       59      24
# estatística qui²: 55.77
# p-valor da estatística: 0.0
#
# ('idade', 'ps.descanco')
#
# ps.descanco     ps_baixa  ps_media  ps_alta
# idade
# menores_idades       153       115       48
# idades_medias         92       157       65
# maiores_idades        62       119      107
# estatística qui²: 74.48
# p-valor da estatística: 0.0
#
# ('idade', 'colesterol')
#
# colesterol      col_baixo  col_medio  col_alto
# idade
# menores_idades         90        126       100
# idades_medias         102        106       106
# maiores_idades        117         72        99
# estatística qui²: 17.3
# p-valor da estatística: 0.0017
#
# ('idade', 'acucar.sangue')
#
# acucar.sangue   Diabetes  Normal
# idade
# menores_idades        36     280
# idades_medias         85     229
# maiores_idades        93     195
# estatística qui²: 40.58
# p-valor da estatística: 0.0
#
# ('idade', 'ecg.descanco')
#
# ecg.descanco    Anormal_ST  Hipertrofia_VE  Normal
# idade
# menores_idades          41              41     234
# idades_medias           66              70     178
# maiores_idades          71              77     140
# estatística qui²: 43.11
# p-valor da estatística: 0.0
#
# ('idade', 'bc.max')
#
# bc.max          bc_baixo  bc_medio  bc_alto
# idade
# menores_idades        62       109      145
# idades_medias        121       110       83
# maiores_idades       140        98       50
# estatística qui²: 80.38
# p-valor da estatística: 0.0
#
# ('idade', 'angina.exerc')
#
# angina.exerc    Nao  Sim
# idade
# menores_idades  229   87
# idades_medias   181  133
# maiores_idades  137  151
# estatística qui²: 39.54
# p-valor da estatística: 0.0
#
# ('idade', 'doenca.card')
#
# doenca.card     Nao  Sim
# idade
# menores_idades  191  125
# idades_medias   139  175
# maiores_idades   80  208
# estatística qui²: 65.08
# p-valor da estatística: 0.0
#
# ('sexo', 'dor.peito')
#
# dor.peito  Assintomatico  Atipica  Sem_Dor  Tipica
# sexo
# Feminino              70       60       53      10
# Masculino            426      113      150      36
# estatística qui²: 36.88
# p-valor da estatística: 0.0
#
# ('sexo', 'ps.descanco')
#
# ps.descanco  ps_baixa  ps_media  ps_alta
# sexo
# Feminino           70        80       43
# Masculino         237       311      177
# estatística qui²: 0.95
# p-valor da estatística: 0.6223
#
# ('sexo', 'colesterol')
#
# colesterol  col_baixo  col_medio  col_alto
# sexo
# Feminino           39         68        86
# Masculino         270        236       219
# estatística qui²: 22.92
# p-valor da estatística: 0.0
#
# ('sexo', 'acucar.sangue')
#
# acucar.sangue  Diabetes  Normal
# sexo
# Feminino             26     167
# Masculino           188     537
# estatística qui²: 12.55
# p-valor da estatística: 0.0004
#
# ('sexo', 'ecg.descanco')
#
# ecg.descanco  Anormal_ST  Hipertrofia_VE  Normal
# sexo
# Feminino              28              47     118
# Masculino            150             141     434
# estatística qui²: 4.84
# p-valor da estatística: 0.0891
#
# ('sexo', 'bc.max')
#
# bc.max     bc_baixo  bc_medio  bc_alto
# sexo
# Feminino         39        64       90
# Masculino       284       253      188
# estatística qui²: 37.28
# p-valor da estatística: 0.0
#
# ('sexo', 'angina.exerc')
#
# angina.exerc  Nao  Sim
# sexo
# Feminino      150   43
# Masculino     397  328
# estatística qui²: 32.43
# p-valor da estatística: 0.0
#
# ('sexo', 'doenca.card')
#
# doenca.card  Nao  Sim
# sexo
# Feminino     143   50
# Masculino    267  458
# estatística qui²: 84.15
# p-valor da estatística: 0.0
#
# ('dor.peito', 'ps.descanco')
#
# ps.descanco    ps_baixa  ps_media  ps_alta
# dor.peito
# Assintomatico       154       209      133
# Atipica              68        78       27
# Sem_Dor              71        89       43
# Tipica               14        15       17
# estatística qui²: 14.94
# p-valor da estatística: 0.0207
#
# ('dor.peito', 'colesterol')
#
# colesterol     col_baixo  col_medio  col_alto
# dor.peito
# Assintomatico        188        142       166
# Atipica               35         68        70
# Sem_Dor               72         76        55
# Tipica                14         18        14
# estatística qui²: 24.07
# p-valor da estatística: 0.0005
#
# ('dor.peito', 'acucar.sangue')
#
# acucar.sangue  Diabetes  Normal
# dor.peito
# Assintomatico       141     355
# Atipica              19     154
# Sem_Dor              41     162
# Tipica               13      33
# estatística qui²: 23.7
# p-valor da estatística: 0.0
#
# ('dor.peito', 'ecg.descanco')
#
# ecg.descanco   Anormal_ST  Hipertrofia_VE  Normal
# dor.peito
# Assintomatico         110             102     284
# Atipica                27              23     123
# Sem_Dor                33              47     123
# Tipica                  8              16      22
# estatística qui²: 19.36
# p-valor da estatística: 0.0036
#
# ('dor.peito', 'bc.max')
#
# bc.max         bc_baixo  bc_medio  bc_alto
# dor.peito
# Assintomatico       233       179       84
# Atipica              26        60       87
# Sem_Dor              55        60       88
# Tipica                9        18       19
# estatística qui²: 113.96
# p-valor da estatística: 0.0
#
# ('dor.peito', 'angina.exerc')
#
# angina.exerc   Nao  Sim
# dor.peito
# Assintomatico  199  297
# Atipica        156   17
# Sem_Dor        152   51
# Tipica          40    6
# estatística qui²: 179.27
# p-valor da estatística: 0.0
#
# ('dor.peito', 'doenca.card')
#
# doenca.card    Nao  Sim
# dor.peito
# Assintomatico  104  392
# Atipica        149   24
# Sem_Dor        131   72
# Tipica          26   20
# estatística qui²: 268.07
# p-valor da estatística: 0.0
#
# ('ps.descanco', 'colesterol')
#
# colesterol   col_baixo  col_medio  col_alto
# ps.descanco
# ps_baixa           116        107        84
# ps_media           122        130       139
# ps_alta             71         67        82
# estatística qui²: 8.03
# p-valor da estatística: 0.0905
#
# ('ps.descanco', 'acucar.sangue')
#
# acucar.sangue  Diabetes  Normal
# ps.descanco
# ps_baixa             59     248
# ps_media             88     303
# ps_alta              67     153
# estatística qui²: 9.3
# p-valor da estatística: 0.0096
#
# ('ps.descanco', 'ecg.descanco')
#
# ecg.descanco  Anormal_ST  Hipertrofia_VE  Normal
# ps.descanco
# ps_baixa              45              54     208
# ps_media              78              83     230
# ps_alta               55              51     114
# estatística qui²: 14.93
# p-valor da estatística: 0.0049
#
# ('ps.descanco', 'bc.max')
#
# bc.max       bc_baixo  bc_medio  bc_alto
# ps.descanco
# ps_baixa           98       105      104
# ps_media          122       144      125
# ps_alta           103        68       49
# estatística qui²: 18.93
# p-valor da estatística: 0.0008
#
# ('ps.descanco', 'angina.exerc')
#
# angina.exerc  Nao  Sim
# ps.descanco
# ps_baixa      213   94
# ps_media      227  164
# ps_alta       107  113
# estatística qui²: 23.56
# p-valor da estatística: 0.0
#
# ('ps.descanco', 'doenca.card')
#
# doenca.card  Nao  Sim
# ps.descanco
# ps_baixa     155  152
# ps_media     185  206
# ps_alta       70  150
# estatística qui²: 20.01
# p-valor da estatística: 0.0
#
# ('colesterol', 'acucar.sangue')
#
# acucar.sangue  Diabetes  Normal
# colesterol
# col_baixo           106     203
# col_medio            50     254
# col_alto             58     247
# estatística qui²: 32.05
# p-valor da estatística: 0.0
#
# ('colesterol', 'ecg.descanco')
#
# ecg.descanco  Anormal_ST  Hipertrofia_VE  Normal
# colesterol
# col_baixo             78              36     195
# col_medio             51              64     189
# col_alto              49              88     168
# estatística qui²: 32.48
# p-valor da estatística: 0.0
#
# ('colesterol', 'bc.max')
#
# bc.max      bc_baixo  bc_medio  bc_alto
# colesterol
# col_baixo        145       104       60
# col_medio         85       110      109
# col_alto          93       103      109
# estatística qui²: 37.04
# p-valor da estatística: 0.0
#
# ('colesterol', 'angina.exerc')
#
# angina.exerc  Nao  Sim
# colesterol
# col_baixo     188  121
# col_medio     187  117
# col_alto      172  133
# estatística qui²: 1.96
# p-valor da estatística: 0.3749
#
# ('colesterol', 'doenca.card')
#
# doenca.card  Nao  Sim
# colesterol
# col_baixo    103  206
# col_medio    169  135
# col_alto     138  167
# estatística qui²: 30.78
# p-valor da estatística: 0.0
#
# ('acucar.sangue', 'ecg.descanco')
#
# ecg.descanco   Anormal_ST  Hipertrofia_VE  Normal
# acucar.sangue
# Diabetes               61              42     111
# Normal                117             146     441
# estatística qui²: 15.22
# p-valor da estatística: 0.0005
#
# ('acucar.sangue', 'bc.max')
#
# bc.max         bc_baixo  bc_medio  bc_alto
# acucar.sangue
# Diabetes             91        76       47
# Normal              232       241      231
# estatística qui²: 10.73
# p-valor da estatística: 0.0047
#
# ('acucar.sangue', 'angina.exerc')
#
# angina.exerc   Nao  Sim
# acucar.sangue
# Diabetes       116   98
# Normal         431  273
# estatística qui²: 3.07
# p-valor da estatística: 0.0798
#
# ('acucar.sangue', 'doenca.card')
#
# doenca.card    Nao  Sim
# acucar.sangue
# Diabetes        44  170
# Normal         366  338
# estatística qui²: 64.32
# p-valor da estatística: 0.0
#
# ('ecg.descanco', 'bc.max')
#
# bc.max          bc_baixo  bc_medio  bc_alto
# ecg.descanco
# Anormal_ST            85        66       27
# Hipertrofia_VE        49        63       76
# Normal               189       188      175
# estatística qui²: 33.18
# p-valor da estatística: 0.0
#
# ('ecg.descanco', 'angina.exerc')
#
# angina.exerc    Nao  Sim
# ecg.descanco
# Anormal_ST       87   91
# Hipertrofia_VE  115   73
# Normal          345  207
# estatística qui²: 10.62
# p-valor da estatística: 0.0049
#
# ('ecg.descanco', 'doenca.card')
#
# doenca.card     Nao  Sim
# ecg.descanco
# Anormal_ST       61  117
# Hipertrofia_VE   82  106
# Normal          267  285
# estatística qui²: 10.93
# p-valor da estatística: 0.0042
#
# ('bc.max', 'angina.exerc')
#
# angina.exerc  Nao  Sim
# bc.max
# bc_baixo      124  199
# bc_medio      184  133
# bc_alto       239   39
# estatística qui²: 140.94
# p-valor da estatística: 0.0
#
# ('bc.max', 'doenca.card')
#
# doenca.card  Nao  Sim
# bc.max
# bc_baixo      71  252
# bc_medio     141  176
# bc_alto      198   80
# estatística qui²: 146.59
# p-valor da estatística: 0.0
#
# ('angina.exerc', 'doenca.card')
#
# doenca.card   Nao  Sim
# angina.exerc
# Nao           355  192
# Sim            55  316
# estatística qui²: 222.26
# p-valor da estatística: 0.0

# %% [markdown]
# ### Elaborando a ANACOR

# %%
mca = prince.MCA(n_components=2).fit(dados_mca)

# %% [markdown]
# ### Quantidade total de dimensões

# %%
# Quantidade de dimensões = qtde total de categorias - qtde de variáveis

# Quantidade total de categorias
mca.J_

# Quantidade de variáveis na análise
mca.K_

# Quantidade de dimensões
quant_dim = mca.J_ - mca.K_

# Resumo das informações
print(f"quantidade total de categorias: {mca.J_}")
print(f"quantidade de variáveis: {mca.K_}")
print(f"quantidade de dimensões: {quant_dim}")
# Out:
# quantidade total de categorias: 27
# quantidade de variáveis: 10
# quantidade de dimensões: 17

# %% [markdown]
# ### Obtendo os eigenvalues

# %%
tabela_autovalores = mca.eigenvalues_summary
print(tabela_autovalores)
# Out:
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              0.285        16.78%                     16.78%
# 1              0.138         8.14%                     24.92%

# %% [markdown]
# ### Inércia principal total

# %%
# Soma de todos os autovalores (todas as dimensões existentes)
print(mca.total_inertia_)
# Out:
# 1.6999999999999933

# %% [markdown]
# ### Obtendo as coordenadas principais das categorias das variáveis

# %%
coord_burt = mca.column_coordinates(dados_mca)
print(coord_burt)
# Out:
#                                     0         1
# idade_menores_idades         0.632520 -0.536397
# idade_idades_medias         -0.064234  0.000927
# idade_maiores_idades        -0.623982  0.587536
# sexo_Feminino                0.817784  0.575840
# sexo_Masculino              -0.217700 -0.153293
# dor.peito_Assintomatico     -0.603308 -0.124449
# dor.peito_Atipica            1.111320 -0.169586
# dor.peito_Sem_Dor            0.460685  0.121335
# dor.peito_Tipica             0.292687  1.444215
# ps.descanco_ps_baixa         0.321364 -0.647352
# ps.descanco_ps_media         0.032316  0.143192
# ps.descanco_ps_alta         -0.505884  0.648858
# colesterol_col_baixo        -0.401161 -0.536284
# colesterol_col_medio         0.326836 -0.116945
# colesterol_col_alto          0.080658  0.659879
# acucar.sangue_Diabetes      -0.693982  0.099285
# acucar.sangue_Normal         0.210955 -0.030180
# ecg.descanco_Anormal_ST     -0.566819 -0.001728
# ecg.descanco_Hipertrofia_VE  0.034275  1.249696
# ecg.descanco_Normal          0.171105 -0.425064
# bc.max_bc_baixo             -0.747956 -0.177189
# bc.max_bc_medio             -0.028012 -0.059185
# bc.max_bc_alto               0.900970  0.273359
# angina.exerc_Nao             0.550835  0.024889
# angina.exerc_Sim            -0.812148 -0.036696
# doenca.card_Nao              0.881894  0.070829
# doenca.card_Sim             -0.711765 -0.057165

# %% [markdown]
# ### Obtendo as coordenadas-padrão das categorias das variáveis

# %%
coord_padrao = mca.column_coordinates(dados_mca)/np.sqrt(mca.eigenvalues_)
print(coord_padrao)
# Out:
#                                     0         1
# idade_menores_idades         1.184300 -1.441700
# idade_idades_medias         -0.120269  0.002491
# idade_maiores_idades        -1.168314  1.579149
# sexo_Feminino                1.531180  1.547715
# sexo_Masculino              -0.407611 -0.412012
# dor.peito_Assintomatico     -1.129606 -0.334487
# dor.peito_Atipica            2.080782 -0.455805
# dor.peito_Sem_Dor            0.862565  0.326119
# dor.peito_Tipica             0.548013  3.881689
# ps.descanco_ps_baixa         0.601707 -1.739919
# ps.descanco_ps_media         0.060507  0.384864
# ps.descanco_ps_alta         -0.947192  1.743969
# colesterol_col_baixo        -0.751115 -1.441398
# colesterol_col_medio         0.611952 -0.314320
# colesterol_col_alto          0.151020  1.773591
# acucar.sangue_Diabetes      -1.299378  0.266854
# acucar.sangue_Normal         0.394981 -0.081118
# ecg.descanco_Anormal_ST     -1.061285 -0.004645
# ecg.descanco_Hipertrofia_VE  0.064175  3.358870
# ecg.descanco_Normal          0.320369 -1.142465
# bc.max_bc_baixo             -1.400437 -0.476239
# bc.max_bc_medio             -0.052449 -0.159075
# bc.max_bc_alto               1.686933  0.734720
# angina.exerc_Nao             1.031357  0.066895
# angina.exerc_Sim            -1.520627 -0.098630
# doenca.card_Nao              1.651216  0.190370
# doenca.card_Sim             -1.332674 -0.153645

# %% [markdown]
# ### Obtendo as coordenadas das observações do banco de dados

# %%
# Na função, as coordenadas das observações vêm das coordenadas-padrão
coord_obs = mca.row_coordinates(dados_mca)
print(coord_obs)
# Out:
#             0         1
# 0    0.815386 -0.038266
# 1    0.398071  0.015909
# 2    0.368483 -0.045580
# 3   -0.128005 -0.211002
# 4    0.063387 -0.122339
# ..        ...       ...
# 913  0.243901  0.059224
# 914 -0.573661  0.001379
# 915 -0.588648 -0.375264
# 916  0.600893  0.509067
# 917  0.603350 -0.281572
#
# [918 rows x 2 columns]

# %% [markdown]
# ### Plotando o mapa perceptual (coordenadas-padrão)

# %%
# Primeiro passo: gerar um DataFrame detalhado

chart = coord_padrao.reset_index()

nome_categ=[]
for col in dados_mca:
    nome_categ.append(dados_mca[col].sort_values(ascending=True).unique())
    categorias = pd.DataFrame(nome_categ).stack().reset_index()

var_chart = pd.Series(chart['index'].str.split('_', expand=True).iloc[:,0])

chart_df_mca = pd.DataFrame({'categoria': chart['index'],
                             'obs_x': chart[0],
                             'obs_y': chart[1],
                             'variavel': var_chart,
                             'categoria_id': categorias[0]})

# Segundo passo: gerar o gráfico de pontos
    
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x'] + 0.03, point['y'] - 0.02, point['val'], fontsize=5)

label_point(x = chart_df_mca['obs_x'],
            y = chart_df_mca['obs_y'],
            val = chart_df_mca['categoria_id'],
            ax = plt.gca())

sns.scatterplot(data=chart_df_mca, x='obs_x', y='obs_y', hue='variavel', s=20)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.axhline(y=0, color='lightgrey', ls='--', linewidth=0.8)
plt.axvline(x=0, color='lightgrey', ls='--', linewidth=0.8)
plt.tick_params(size=2, labelsize=6)
plt.legend(bbox_to_anchor=(1.25,-0.2), fancybox=True, shadow=True, ncols=10, fontsize='5')
plt.title("Mapa Perceptual - MCA", fontsize=12)
plt.xlabel(f"Dim. 1: {tabela_autovalores.iloc[0,1]} da inércia", fontsize=8)
plt.ylabel(f"Dim. 2: {tabela_autovalores.iloc[1,1]} da inércia", fontsize=8)
plt.show()

# %% [markdown]
# ### Gráfico das observações

# %%
coord_obs['doenca.card'] = dados_mca['doenca.card']

sns.scatterplot(data=coord_obs, x=0, y=1, hue='doenca.card', s=20)
plt.title("Mapa das Observações - MCA", fontsize=12)
plt.xlabel("Dimensão 1", fontsize=8)
plt.ylabel("Dimensão 2", fontsize=8)
plt.show()
